# %% [markdown]
# # 🔮 Retail Sales Forecasting with Prophet

# %% [markdown]
# This notebook uses Facebook Prophet to forecast daily retail sales based on historical transaction data.

# %%
import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("mock_kaggle.csv")

# Convert and rename columns for Prophet
df['data'] = pd.to_datetime(df['data'])
df = df.rename(columns={'data': 'ds', 'venda': 'y'})

# Keep only necessary columns
df = df[['ds', 'y']]
df.head()
# Out:
#           ds   y
# 0 2014-01-01   0
# 1 2014-01-02  70
# 2 2014-01-03  59
# 3 2014-01-04  93
# 4 2014-01-05  96

# %%
# Initialize and train Prophet model
model = Prophet(daily_seasonality=True)
model.fit(df)
# Out:
# 17:29:30 - cmdstanpy - INFO - Chain [1] start processing
# 17:29:30 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Create future dataframe and forecast
future = model.make_future_dataframe(periods=90)
forecast = model.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds        yhat  yhat_lower  yhat_upper
# 1022 2016-10-25  203.431933  113.862814  285.818689
# 1023 2016-10-26  231.564852  148.491995  311.913310
# 1024 2016-10-27  219.738774  137.687185  299.135809
# 1025 2016-10-28  234.970159  158.328600  320.958273
# 1026 2016-10-29  289.481150  197.622721  372.956305

# %%
# Plot forecast
fig1 = model.plot(forecast)
plt.title("Forecasted Retail Sales")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.grid(True)
plt.show()

# %%
# Plot forecast components
fig2 = model.plot_components(forecast)
plt.show()

# %%
# Export forecast to CSV
forecast.to_csv("sales_forecast.csv", index=False)
print("Forecast exported to sales_forecast.csv")
# Out:
# Forecast exported to sales_forecast.csv
